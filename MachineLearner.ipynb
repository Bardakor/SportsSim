# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0        Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0     0
# 1    Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0     1
# 2  Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0     0
# 3    Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0     0
# 4         Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0     0
#
#    season       team
# 0    2024  Liverpool
# 1    2024  Liverpool
# 2    2024  Liverpool
# 3    2024  Liverpool
# 4    2024  Liverpool
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1272, 27)

# %%
#2 seasons, 20 squads, 38 matches

2 * 20 * 38
# Out:
# 1520

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   64
# Newcastle United            64
# Everton                     64
# Nottingham Forest           64
# Crystal Palace              64
# Manchester City             64
# Fulham                      64
# Brighton and Hove Albion    64
# Manchester United           64
# Aston Villa                 64
# Arsenal                     64
# West Ham United             63
# Chelsea                     63
# Wolverhampton Wanderers     63
# Tottenham Hotspur           63
# Bournemouth                 63
# Brentford                   63
# Leicester City              38
# Leeds United                38
# Southampton                 38
# Burnley                     26
# Luton Town                  25
# Sheffield United            25
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D  2.0
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D  1.0
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L  1.0
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  9.0
# 5   2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 34  2024-01-31  20:15  Premier League  Matchweek 22  Wed  Home      W  4.0
# 35  2024-02-04  16:30  Premier League  Matchweek 23  Sun  Away      L  1.0
# 36  2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home      W  3.0
# 37  2024-02-17  12:30  Premier League  Matchweek 25  Sat  Away      W  4.0
# 38  2024-02-21  19:30  Premier League  Matchweek 26  Wed  Home      W  4.0
#
#      ga        opponent  ...  match report  notes    sh   sot  dist   fk pk  \
# 1   2.0          Fulham  ...  Match Report    NaN  11.0   3.0  12.4  0.0  0
# 2   1.0  Crystal Palace  ...  Match Report    NaN  24.0   4.0  17.4  0.0  0
# 3   2.0  Manchester Utd  ...  Match Report    NaN  17.0   5.0  14.4  0.0  0
# 4   0.0     Bournemouth  ...  Match Report    NaN  19.0  12.0  11.6  0.0  0
# 5   1.0   Newcastle Utd  ...  Match Report    NaN  23.0   6.0  17.8  0.0  0
# ..  ...             ...  ...           ...    ...   ...   ...   ...  ... ..
# 34  1.0         Chelsea  ...  Match Report    NaN  27.0  13.0  19.9  2.0  0
# 35  3.0         Arsenal  ...  Match Report    NaN  10.0   1.0  19.7  0.0  0
# 36  1.0         Burnley  ...  Match Report    NaN  25.0  10.0  15.4  0.0  0
# 37  1.0       Brentford  ...  Match Report    NaN  15.0   8.0  15.9  1.0  0
# 38  1.0      Luton Town  ...  Match Report    NaN  29.0  13.0  16.9  0.0  0
#
#    pkatt  season       team
# 1      0    2023  Liverpool
# 2      0    2023  Liverpool
# 3      0    2023  Liverpool
# 4      0    2023  Liverpool
# 5      0    2023  Liverpool
# ..   ...     ...        ...
# 34     1    2024  Liverpool
# 35     0    2024  Liverpool
# 36     0    2024  Liverpool
# 37     0    2024  Liverpool
# 38     0    2024  Liverpool
#
# [64 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 14    40
# Matchweek 25    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 2     40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 16    40
# Matchweek 15    40
# Matchweek 20    40
# Matchweek 13    40
# Matchweek 12    40
# Matchweek 11    40
# Matchweek 10    40
# Matchweek 9     40
# Matchweek 8     40
# Matchweek 7     40
# Matchweek 6     40
# Matchweek 5     40
# Matchweek 4     40
# Matchweek 3     40
# Matchweek 17    38
# Matchweek 26    34
# Matchweek 27    20
# Matchweek 29    20
# Matchweek 30    20
# Matchweek 31    20
# Matchweek 33    20
# Matchweek 34    20
# Matchweek 28    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 32    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
#deleted comp and notes
del matches["comp"]
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 0  2023-08-13  16:30   Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00   Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30   Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00   Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30   Matchweek 5  Sat  Away      W  3.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2023-04-30  14:00  Matchweek 34  Sun  Away      L  1.0  3.0
# 43 2023-05-08  20:00  Matchweek 35  Mon  Away      L  3.0  4.0
# 44 2023-05-13  15:00  Matchweek 36  Sat  Home      L  0.0  2.0
# 45 2023-05-21  14:00  Matchweek 37  Sun  Away      L  1.0  3.0
# 46 2023-05-28  16:30  Matchweek 38  Sun  Home      D  4.0  4.0
#
#            opponent   xg  ...  match report    sh   sot  dist   fk pk pkatt  \
# 0           Chelsea  1.3  ...  Match Report  13.0   1.0  17.8  0.0  0     0
# 1       Bournemouth  3.0  ...  Match Report  25.0   9.0  16.8  1.0  0     1
# 2     Newcastle Utd  0.9  ...  Match Report   9.0   4.0  17.2  1.0  0     0
# 3       Aston Villa  2.5  ...  Match Report  17.0   4.0  14.7  0.0  0     0
# 4            Wolves  2.5  ...  Match Report  16.0   5.0  15.8  0.0  0     0
# ..              ...  ...  ...           ...   ...   ...   ...  ... ..   ...
# 42    Newcastle Utd  0.8  ...  Match Report   4.0   3.0  17.3  0.0  0     0
# 43  Nott'ham Forest  3.1  ...  Match Report  18.0   4.0  14.0  0.0  1     1
# 44           Fulham  0.4  ...  Match Report   5.0   1.0  24.2  0.0  0     0
# 45         Brighton  0.6  ...  Match Report   5.0   1.0  13.8  1.0  0     0
# 46        Liverpool  1.8  ...  Match Report  15.0  10.0  17.5  1.0  0     0
#
#     season         team  target
# 0     2024    Liverpool       0
# 1     2024    Liverpool       1
# 2     2024    Liverpool       1
# 3     2024    Liverpool       1
# 4     2024    Liverpool       1
# ..     ...          ...     ...
# 42    2023  Southampton       0
# 43    2023  Southampton       0
# 44    2023  Southampton       0
# 45    2023  Southampton       0
# 46    2023  Southampton       0
#
# [1272 rows x 26 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue", "opponent", "time", "date"]

# %%
train.columns
# Out:
# Index(['date', 'time', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt',
#        'season', 'team', 'target'],
#       dtype='object')

# %%
rf.fit(train[predictors], train["target"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12472\3260456119.py in ?()
# ----> 1 rf.fit(train[predictors], train["target"])
#
# c:\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# c:\Python312\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     359         # Validate or convert input data
#     360         if issparse(y):
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     362
# --> 363         X, y = self._validate_data(
#     364             X,
#     365             y,
#     366             multi_output=True,
#
# c:\Python312\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1259         raise ValueError(
#    1260             f"{estimator_name} requires y to be passed, but the target y is None"
#    1261         )
#    1262
# -> 1263     X = check_array(
#    1264         X,
#    1265         accept_sparse=accept_sparse,
#    1266         accept_large_sparse=accept_large_sparse,
#
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# c:\Python312\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Away'
